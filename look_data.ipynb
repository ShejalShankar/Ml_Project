# %%
import pickle as pkl
import cv2
import matplotlib.pyplot as plt

# %%
f = open("prediction.pkl", 'rb')
g = open("Dataset1/TUSimple/testing_sample.pkl",'rb')
#h =open("Dataset1/TUSimple/train_set/training_samples1.pkl",'rb')

# %%
data = pkl.load(f)
data1 = pkl.load(g)
#img_data = pkl.load(h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pkl.load(f)
#       2 data1 = pkl.load(g)
#       3 #img_data = pkl.load(h)
#
# NameError: name 'pkl' is not defined

# %%
print(len(data1))
# Out:
# 2782

# %%
plt.imshow(data1[0]['label'])

# %%
plt.imshow(data[4])

# %%
plt.imshow(data1[20]['image'])
